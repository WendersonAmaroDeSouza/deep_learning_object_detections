# %%
import os
import urllib

# %%
def download_images(main_dir,urls_filename):
    class_name = urls_filename.split('.')[-2]
    output_dir = main_dir+os.sep+class_name
    os.makedirs(output_dir,exist_ok=True)
    with open(urls_filename) as f:
        for url in f:
            img_filename = url.split('/')[-1].replace("\n","")
            print(img_filename)
            try:
                response = urllib.request.urlopen(url)
                open(output_dir+'/'+img_filename,mode="wb+").write(response.read())
            except:
                print('nao conseguiu baixar ',url)

# %%
''' download_images('./', 'vassouras.csv')
download_images('./', 'chinelos.csv')
download_images('./', 'ferros_de_passar_roupas.csv')
download_images('./', 'carros.csv')
download_images('./', 'canetas.csv')
download_images('./', 'livros.csv')
download_images('./', 'pratos.csv')
download_images('./', 'copos.csv')
download_images('./', 'xicaras.csv')
download_images('./', 'prendedores_de_roupas.csv')
download_images('./', 'facas.csv')
download_images('./', 'colheres.csv')
download_images('./', 'garfos.csv')
download_images('./', 'chaves.csv') ''' 
download_images('./', 'rodos.csv')
# Out:
# 9k=
# Z
# gLALCRciSH8UgAAAABJRU5ErkJggg==
# 9k=
# 9k=
# n3LTOtGGxkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRkZGRk9CP9F4L1zAhpAb4KAAAAAElFTkSuQmCC
# 9k=
# g0r4BUhladf7wAAAABJRU5ErkJggg==
# 2Q==
# QNh4V5edlC4fQAAAABJRU5ErkJggg==
# wJXPsjtpvAAAAAElFTkSuQmCC
# 2Q==
# JzpisgerkAAAAASUVORK5CYII=
# QSvmrv3l2BwAAAABJRU5ErkJggg==
# 9k=
# 2Q==
# 9k=
# 9k=
# 9ctoPk5C+h17YUYgQIUKECBEiRIgQIUKECBEiRIgQIUKECBEiRIgQbvwPdnOwWI3Hcv8AAAAASUVORK5CYII=
# 2Q==
# images?q=tbn:ANd9GcSKYLa9i_R_Ip18TV8Bm-EWFTgZRYsQ3jJ7Zw&usqp=CAU
# nao conseguiu baixar  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSKYLa9i_R_Ip18TV8Bm-EWFTgZRYsQ3jJ7Zw&usqp=CAU
#
# images?q=tbn:ANd9GcSEqX7eqBjR51zdLpSRN1WZCPZWE_ZjqGGoSQ&usqp=CAU
# nao conseguiu baixar  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSEqX7eqBjR51zdLpSRN1WZCPZWE_ZjqGGoSQ&usqp=CAU
#
# images?q=tbn:ANd9GcStEzhb-rQmOG7dWQPDZkSH03V1hgMufATClA&usqp=CAU
# ...
